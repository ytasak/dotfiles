# %% [markdown]
# # Notebook Preview Sample
#
# This is a **markdown** cell used to test the preview.
#
# - Bullet one
# - Bullet two

# %%
import math
value = math.sqrt(81)
value

# %% [raw]
# Raw cell content goes here.
